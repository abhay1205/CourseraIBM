# %%
import pandas as pd
import numpy as np
print('done')
# Out:
# done

# %%
df_map = pd.read_csv('https://cocl.us/sanfran_crime_dataset')

# %%
df_map.head(10)
# Out:
#    IncidntNum        Category                                        Descript  \
# 0   120058272     WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1   120058272     WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2   141059263        WARRANTS                                  WARRANT ARREST
# 3   160013662    NON-CRIMINAL                                   LOST PROPERTY
# 4   160002740    NON-CRIMINAL                                   LOST PROPERTY
# 5   160002869         ASSAULT                                         BATTERY
# 6   160003130  OTHER OFFENSES                                PAROLE VIOLATION
# 7   160003259    NON-CRIMINAL                                     FIRE REPORT
# 8   160003970        WARRANTS                                  WARRANT ARREST
# 9   160003641  MISSING PERSON                                    FOUND PERSON
#
#   DayOfWeek                    Date   Time  PdDistrict      Resolution  \
# ...

# %%
df_map.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150500 entries, 0 to 150499
# Data columns (total 13 columns):
# IncidntNum    150500 non-null int64
# Category      150500 non-null object
# Descript      150500 non-null object
# DayOfWeek     150500 non-null object
# Date          150500 non-null object
# Time          150500 non-null object
# PdDistrict    150499 non-null object
# Resolution    150500 non-null object
# Address       150500 non-null object
# X             150500 non-null float64
# Y             150500 non-null float64
# Location      150500 non-null object
# PdId          150500 non-null int64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 14.9+ MB

# %%
df_stat = df_map[['PdDistrict']]
df_stat = df_stat.groupby(['PdDistrict'], as_index=False).sum()
df_sta = df_map['PdDistrict'].value_counts()
df_stat.rename(columns={'PdDistrict': 'Neighborhood'} ,inplace=True)
df_stat.index.name
df_stat
df_sta
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-19d566518dfc> in <module>
#       5 df_stat.index.name
#       6 df_stat
# ----> 7 df_sta.dtype()
#
# TypeError: 'numpy.dtype' object is not callable

# %%
df_map[['PdDistrict', 'IncidntNum' ]]

# %%
df_test = df_map[['PdDistrict', 'IncidntNum']]
df_grp = df_test.groupby(['PdDistrict'], as_index=False).sum()
df_grp['Count'] = 
df_grp

# %%
df_grp.sort_values(by='IncidntNum',  ascending=False, axis=0, inplace=True)
df_grp

# %%
df_grp.rename(columns={'PdDistrict':'Neighborhood', 'IncidntNum':'Count'}, inplace=True)
df_grp['Reduced'] = df_grp[['Count']]/100000000
df_grp

# %%
import folium

# %%
# san_geo = r'san-francisco.geojson'

world_map = folium.Map(location=[37.77, -122.42], zoom_start=12)
world_map

# %%
san_geo = 'https://cocl.us/sanfran_geojson'

threshold_scale = np.linspace(df_grp['Count'].min(),
                              df_grp['Count'].max(),
                              6, dtype=int)

threshold_scale = threshold_scale.tolist()
threshold_scale[-1] = threshold_scale[-1] + 1

m = folium.Map( location=[37.77, -122.42], zoom_start =12)

folium.Choropleth(
    geo_data = san_geo,
    name='choropleth',
    data=df_grp,
    columns=['Neighborhood', 'Count'],
    key_on = 'feature.properties.DISTRICT',
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Crime Rate in San Francisco',
    ).add_to(m)

folium.LayerControl().add_to(m)
m
