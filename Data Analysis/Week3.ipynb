# %%
import numpy as np
import pandas as pd
print('done')
# Out:
# done

# %%
path='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/automobileEDA.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %%
df[['bore', 'stroke', 'compression-ratio', 'horsepower']].corr()
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566936
# stroke            -0.055390  1.000000           0.187923    0.098462
# compression-ratio  0.001263  0.187923           1.000000   -0.214514
# horsepower         0.566936  0.098462          -0.214514    1.000000

# %%
sns.regplot(x='engine-size', y='price', data = df)
plt.ylim(0,)
# Out:
# (0, 55922.30219857719)

# %%
df[['engine-size','price']].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %%
df[['highway-mpg', 'price']].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %%
sns.regplot(x='highway-mpg', y='price', data=df)
plt.ylim(0,)
# Out:
# (0, 48301.880751698554)

# %%
sns.regplot(x='peak-rpm', y='price', data=df)

# %%
df[['peak-rpm', 'price']].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101616
# price    -0.101616  1.000000

# %%
df[['stroke', 'price']].corr()
# Out:
#          stroke    price
# stroke  1.00000  0.08231
# price   0.08231  1.00000

# %%
sns.regplot(x='stroke', y='price', data=df)
plt.ylim(0,)
# Out:
# (0, 47436.15466888818)

# %%
sns.boxplot(x='body-style', y='price', data=df)

# %%
sns.boxplot(x='engine-location', y='price', data=df)

# %%
sns.boxplot(x='drive-wheels', y='price', data=df)

# %%
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# ...

# %%
df.describe(include=['object'])
# Out:
#           make aspiration num-of-doors body-style drive-wheels  \
# count      201        201          201        201          201
# unique      22          2            2          5            3
# top     toyota        std         four      sedan          fwd
# freq        32        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system  \
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92
#
#        horsepower-binned
# count                200
# unique                 3
# top                  Low
# freq                 115

# %%
df['drive-wheels'].value_counts()
# Out:
# fwd    118
# rwd     75
# 4wd      8
# Name: drive-wheels, dtype: int64

# %%
df['drive-wheels'].value_counts().to_frame()
# Out:
#      drive-wheels
# fwd           118
# rwd            75
# 4wd             8

# %%
drive_wheels_counts = df['drive-wheels'].value_counts().to_frame()
drive_wheels_counts.rename(columns={'drive-wheels':'value_counts'}, inplace=True)
drive_wheels_counts
# Out:
#      value_counts
# fwd           118
# rwd            75
# 4wd             8

# %%
drive_wheels_counts.index.name = 'drive-wheels'
drive_wheels_counts
# Out:
#               value_counts
# drive-wheels
# fwd                    118
# rwd                     75
# 4wd                      8

# %%
engine_loc_counts = df['engine-location'].value_counts().to_frame()
engine_loc_counts.rename(columns={'engine-location':'value_counts'}, inplace=True)
engine_loc_counts.index.name = 'engine-location'
engine_loc_counts
# Out:
#                  value_counts
# engine-location
# front                     198
# rear                        3

# %%
df['drive-wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
df_group_one = df[['drive-wheels', 'body-style', 'price']]

# %%
df_group_one =df_group_one.groupby(['drive-wheels'], as_index=False).mean()
df_group_one
# Out:
#   drive-wheels         price
# 0          4wd  10241.000000
# 1          fwd   9244.779661
# 2          rwd  19757.613333

# %%
df_group_test = df[['drive-wheels', 'body-style', 'price']]
df_group_test =df_group_test.groupby(['drive-wheels', 'body-style'], as_index=False).mean()
df_group_test
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
group_pivot = df_group_test.pivot(index='drive-wheels', columns='body-style')
group_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
group_pivot = group_pivot.fillna(0)
group_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  0.0      0.000000   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
group_test = df[['make', 'body-style', 'price']]
group_test = group_test.groupby(['make', 'body-style'], as_index = False).mean()

# %%
group_t_pivot = group_test.pivot(index='make', columns='body-style')
group_t_pivot = group_t_pivot.fillna(0)
group_t_pivot
# Out:
#                     price                                            \
# body-style    convertible       hardtop     hatchback         sedan
# make
# alfa-romero       14997.5      0.000000  16500.000000      0.000000
# audi                  0.0      0.000000      0.000000  17647.000000
# bmw                   0.0      0.000000      0.000000  26118.750000
# chevrolet             0.0      0.000000   5723.000000   6575.000000
# dodge                 0.0      0.000000   7819.800000   7619.666667
# honda                 0.0      0.000000   7054.428571   9945.000000
# isuzu                 0.0      0.000000  11048.000000   6785.000000
# jaguar                0.0      0.000000      0.000000  34600.000000
# mazda                 0.0      0.000000  10085.000000  11464.142857
# mercedes-benz     35056.0  36788.000000      0.000000  33074.000000
# mercury               0.0      0.000000  16503.000000      0.000000
# mitsubishi            0.0      0.000000   9597.888889   8434.000000
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.pcolor(group_pivot, cmap='RdBu')
plt.colorbar()
plt.show()

# %%
fig, ax = plt.subplots()
im = ax.pcolor(group_pivot, cmap = 'RdBu')

row_labels = group_pivot.columns.levels[1]
col_labels = group_pivot.index

ax.set_xticklabels(row_labels, minor=False)
ax.set_yticklabels(col_labels, minor=False)

plt.xticks(rotation=90)

fig.colorbar(im)
plt.show()

# %%
from scipy import stats

# %%
pearson_coff, p_value = stats.pearsonr(df['wheel-base'], df['price'])
print(pearson_coff, p_value)
# Out:
# 0.584641822265508 8.076488270733218e-20

# %%
pearson_coff, p_value = stats.pearsonr(df['horsepower'], df['price'])
print(pearson_coff, p_value)
# Out:
# 0.809574567003656 6.369057428259557e-48

# %%
pearson_coff, p_value = stats.pearsonr(df['length'], df['price'])
print(pearson_coff, p_value)
# Out:
# 0.690628380448364 8.016477466158986e-30

# %%
pearson_coff, p_value = stats.pearsonr(df['width'], df['price'])
print(pearson_coff, p_value)
# Out:
# 0.7512653440522674 9.200335510481516e-38

# %%
pearson_coff, p_value = stats.pearsonr(df['curb-weight'], df['price'])
print(pearson_coff, p_value)
# Out:
# 0.8344145257702846 2.1895772388936914e-53

# %%
pearson_coff, p_value = stats.pearsonr(df['engine-size'], df['price'])
print(pearson_coff, p_value)
# Out:
# 0.8723351674455185 9.265491622198389e-64

# %%
pearson_coff, p_value = stats.pearsonr(df['bore'], df['price'])
print(pearson_coff, p_value)
# Out:
# 0.5431553832626601 8.049189483935489e-17

# %%
pearson_coff, p_value = stats.pearsonr(df['city-mpg'], df['price'])
print(pearson_coff, p_value)
# Out:
# -0.6865710067844677 2.321132065567674e-29

# %%
pearson_coff, p_value = stats.pearsonr(df['highway-mpg'], df['price'])
print(pearson_coff, p_value)
# Out:
# -0.7046922650589529 1.7495471144477352e-31

# %%
group_test2 = df[['drive-wheels', 'price']].groupby(['drive-wheels'])
group_test2.head(10)
# Out:
#     drive-wheels    price
# 0            rwd  13495.0
# 1            rwd  16500.0
# 2            rwd  16500.0
# 3            fwd  13950.0
# 4            4wd  17450.0
# 5            fwd  15250.0
# 6            fwd  17710.0
# 7            fwd  18920.0
# 8            fwd  23875.0
# 9            rwd  16430.0
# 10           rwd  16925.0
# 11           rwd  20970.0
# 12           rwd  21105.0
# 13           rwd  24565.0
# 14           rwd  30760.0
# 15           rwd  41315.0
# 17           fwd   5151.0
# 18           fwd   6295.0
# 19           fwd   6575.0
# 20           fwd   5572.0
# 21           fwd   6377.0
# 136          4wd   7603.0
# 140          4wd   9233.0
# 141          4wd  11259.0
# 144          4wd   8013.0
# 145          4wd  11694.0
# 150          4wd   7898.0
# 151          4wd   8778.0

# %%
group_test2.get_group('4wd')['price']
# Out:
# 4      17450.0
# 136     7603.0
# 140     9233.0
# 141    11259.0
# 144     8013.0
# 145    11694.0
# 150     7898.0
# 151     8778.0
# Name: price, dtype: float64

# %%
# ANOVA
f_val, p_val = stats.f_oneway(group_test2.get_group('fwd')['price'], group_test2.get_group('rwd')['price'], group_test2.get_group('4wd')['price'])
print(f_val, p_val)
# Out:
# 67.95406500780399 3.3945443577151245e-23

# %%
f_val, p_val = stats.f_oneway(group_test2.get_group('fwd')['price'], group_test2.get_group('rwd')['price'])
print(f_val, p_val)
# Out:
# 130.5533160959111 2.2355306355677845e-23
